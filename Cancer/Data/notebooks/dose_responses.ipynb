# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
dose_resp = pd.read_csv("DOSERESP.csv").drop([
    "RELEASE_DATE", 
    "PREFIX",
    "PANEL_NUMBER",
    "CELL_NUMBER",
    "PANEL_NAME",
    "COUNT_GIPRCNT",
    "AVERAGE_GIPRCNT",
    "STDDEV_GIPRCNT",
    "COUNT_PTC",
    "STDDEV_PTC"
], axis=1)
dose_resp = dose_resp[dose_resp["CONCENTRATION_UNIT"] == "M"]
dose_resp.head()
# Out:
#       EXPID     NSC CONCENTRATION_UNIT  LOG_HI_CONCENTRATION  CONCENTRATION  \
# 0  0001MD02  123127                  M               -4.6021        -4.6021
# 1  0001MD02  123127                  M               -4.6021        -4.6021
# 2  0001MD02  123127                  M               -4.6021        -4.6021
# 3  0001MD02  123127                  M               -4.6021        -4.6021
# 4  0001MD02  123127                  M               -4.6021        -5.6021
#
#    CELL_NAME PANEL_CODE  AVERAGE_PTC
# 0     HOP-62        LNS      24.4469
# 1  A549/ATCC        LNS       8.4318
# 2      T-47D        BRE      38.5507
# 3      K-562        LEU      14.3695
# 4       EKVX        LNS      57.3222

# %%
def dose_response(x, logIC50, Hillslope):
    return 100 / (1 + 10 ** ((logIC50 - x) * Hillslope))

def remove_outliers(df):
    df['Outlier'] = False
    df_sorted = df.sort_values(by='CONCENTRATION')
    for conc, group in df_sorted.groupby('CONCENTRATION'):
        Q1 = group['AVERAGE_PTC'].quantile(0.25)
        Q3 = group['AVERAGE_PTC'].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers = group[(group['AVERAGE_PTC'] < lower_bound) | (group['AVERAGE_PTC'] > upper_bound)]
        df.loc[outliers.index, 'Outlier'] = True
    return df

def calculate_IC50(df):
    # Group by NSC and CELL_NAME
    grouped = df.groupby(['NSC', 'CELL_NAME'])
    
    IC50_values = []
    for group_key, group_df in tqdm(grouped, total=len(grouped), desc="Calculating IC50"):
        # Remove outliers within each group
        group_df = remove_outliers(group_df)
        
        if len(group_df) == 0:
            continue
        
        concentrations = group_df['CONCENTRATION']
        responses = group_df['AVERAGE_PTC']

        initial_guess = (0, -1)
        try:
            params, covariance = curve_fit(dose_response, concentrations, responses, p0=initial_guess)
        except RuntimeError:
            continue

        fitted_responses = dose_response(concentrations, *params)
        rmse = np.sqrt(mean_squared_error(responses, fitted_responses))
            
        logIC50 = params[0]
        HillSlope = params[1]

        IC50_values.append({
            'NSC': group_key[0],
            'CELL_NAME': group_key[1],
            'logIC50': logIC50,
            'HillSlope': HillSlope,
            "RMSE": rmse
        })

    IC50_df = pd.DataFrame(IC50_values)

    return IC50_df

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
responses_exp = calculate_IC50(dose_resp)
# Out:
# Calculating IC50:   0%|          | 835/3251600 [01:06<71:53:31, 12.56it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_679/2339301674.py in <module>
# ----> 1 responses_exp = calculate_IC50(dose_resp)
#
# /tmp/ipykernel_679/3033329241.py in calculate_IC50(df)
#      22     for group_key, group_df in tqdm(grouped, total=len(grouped), desc="Calculating IC50"):
#      23         # Remove outliers within each group
# ---> 24         group_df = remove_outliers(group_df)
#      25
#      26         if len(group_df) == 0:
#
# /tmp/ipykernel_679/3033329241.py in remove_outliers(df)
#       6     df_sorted = df.sort_values(by='CONCENTRATION')
#       7     for conc, group in df_sorted.groupby('CONCENTRATION'):
# ----> 8         Q1 = group['AVERAGE_PTC'].quantile(0.25)
#       9         Q3 = group['AVERAGE_PTC'].quantile(0.75)
#      10         IQR = Q3 - Q1
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/series.py in quantile(self, q, interpolation)
#    2444         # We dispatch to DataFrame so that core.internals only has to worry
#    2445         #  about 2D cases.
# -> 2446         df = self.to_frame()
#    2447
#    2448         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/series.py in to_frame(self, name)
#    1746         """
#    1747         if name is None:
# -> 1748             df = self._constructor_expanddim(self)
#    1749         else:
#    1750             df = self._constructor_expanddim({name: self})
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     660             elif getattr(data, "name", None) is not None:
#     661                 # i.e. Series/Index with non-None name
# --> 662                 mgr = dict_to_mgr(
#     663                     # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     664                     # attribute "name"
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     442     else:
#     443         keys = list(data.keys())
# --> 444         columns = data_names = Index(keys)
#     445         arrays = [com.maybe_iterable_to_list(data[k]) for k in keys]
#     446         # GH#24096 need copy to be deep for datetime64tz case
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     493
#     494             subarr = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
# --> 495             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     496
#     497     @classmethod
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, tupleize_cols, **kwargs)
#     457                 arr = data
#     458             else:
# --> 459                 arr = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#     460
#     461                 if dtype is None:
#
# /opt/conda/lib/python3.9/site-packages/pandas/core/common.py in asarray_tuplesafe(values, dtype)
#     244         result = np.asarray(values, dtype=object)
#     245
# --> 246     if result.ndim == 2:
#     247         # Avoid building an array of arrays:
#     248         values = [tuple(x) for x in values]
#
# KeyboardInterrupt:

# %%
responses_exp.head()
# Out:
#       EXPID    NSC  CELL_NAME   logIC50  HillSlope       RMSE
# 0  0001MD02  19893       A498 -0.722969  -0.235588   2.775089
# 1  0001MD02  19893  A549/ATCC -4.190503  -0.306085  10.192824
# 2  0001MD02  19893       ACHN -3.399132  -0.317039   6.586397
# 3  0001MD02  19893     BT-549  0.172110  -0.128231   2.126677
# 4  0001MD02  19893     CAKI-1 -3.257086  -0.241409   6.647007
